# %% [markdown]
# # Статистика

# %%
records_per_second = 1
records_per_day = records_per_second * 60 * 60 * 24
print('records_per_day is ', records_per_day)
all_records = 10e6 #10000000
print('how much days? ', all_records/records_per_day)
# Out:
# records_per_day is  86400
# how much days?  115.74074074074075

# %%
height = [160, 150, 165, 160, 170, 172, 180, 185, 174, 190, 195]
print(height)
height.sort()
print(height)
print('Mean:', sum(height)/len(height))
print('Median:', height[(len(height)//2)])
print('Mode:', max(set(height), key=height.count))
# Out:
# [160, 150, 165, 160, 170, 172, 180, 185, 174, 190]
# [150, 160, 160, 165, 170, 172, 174, 180, 185, 190]
# Mean: 170.6
# Median: 172
# Mode: 160

# %%
import numpy as np
from scipy import stats
np.set_printoptions(suppress=True)
salary_in_thousands = np.array([28, 6.5, 6.5, 6.5, 50, 11, 10, 35, 25, 25, 6.5, 120, 6.5, 50, 50, 55, 0.1], dtype = float)
salary_sorted = np.sort(salary_in_thousands)

print(f'Data {salary_in_thousands}')
print(f'Sorted data {salary_sorted}')

print(f'Mean {np.mean(salary_in_thousands)}')
data, counts = np.unique(salary_in_thousands, return_counts=True)
probabilities = counts / counts.sum()
exp_value = np.sum(data * probabilities)
print(f'Expected value {exp_value}')
print(f'Median {np.median(salary_in_thousands)}')
print(f'Mode {stats.mode(salary_in_thousands)}')
# Out:
# Data [ 28.    6.5   6.5   6.5  50.   11.   10.   35.   25.   25.    6.5 120.
#    6.5  50.   50.   55.    0.1]
# Sorted data [  0.1   6.5   6.5   6.5   6.5   6.5  10.   11.   25.   25.   28.   35.
#   50.   50.   50.   55.  120. ]
# Mean 28.91764705882353
# Expected value 28.91764705882353
# Median 25.0
# Mode ModeResult(mode=6.5, count=5)

# %%
salary_in_thousands_new = np.append(salary_in_thousands, [1000])
salary_sorted_new = np.sort(salary_in_thousands)
print(f'Data {salary_in_thousands_new}')
print(f'Sorted data {salary_sorted_new}')

print(f'Mean {np.mean(salary_in_thousands_new)}')
data, counts = np.unique(salary_in_thousands_new, return_counts=True)
probabilities = counts / counts.sum()
exp_value = np.sum(data * probabilities)
print(f'Expected value {exp_value}')
print(f'Median {np.median(salary_in_thousands_new)}')
print(f'Mode {stats.mode(salary_in_thousands_new)}')
# Out:
# Data [  28.     6.5    6.5    6.5   50.    11.    10.    35.    25.    25.
#     6.5  120.     6.5   50.    50.    55.     0.1 1000. ]
# Sorted data [  0.1   6.5   6.5   6.5   6.5   6.5  10.   11.   25.   25.   28.   35.
#   50.   50.   50.   55.  120. ]
# Mean 82.86666666666666
# Expected value 82.86666666666666
# Median 25.0
# Mode ModeResult(mode=6.5, count=5)

# %%
# Toy data
data_toy = np.array([2, 4, 6, 8, 10, 12, 14, 16], dtype=float) # [2,2,2,2,4,4,4,4,6,6,6,6,8,8,10,10,12,12,14,16]
probabilities_toy = np.array([0.2, 0.2, 0.2, 0.1, 0.1, 0.1, 0.05, 0.05])
print("Cереднє аріфм.:", np.mean(data_toy))
print("Математичне очікування:", np.sum(data_toy * probabilities_toy))
# Out:
# Cереднє аріфм.: 9.0
# Математичне очікування: 6.9

# %%
print(f'Data is \n{salary_in_thousands_new}')

print(f'Мінімальне значення:{np.min(salary_in_thousands_new)}')
print(f'Максимальне значення:{np.max(salary_in_thousands_new)}')
print(f'Розмах значення:{np.ptp(salary_in_thousands_new)}')
print(f'Дисперсія (середньо квадратичне відхилення) значення:{np.var(salary_in_thousands_new)}')
print(f'Стандартне відхилення значення:{np.std(salary_in_thousands_new)}')
age = np.array([28.0, 24.0, 50.1, 34.2, 21.0, 16.8, 65.7, 54.8, 43.33, 31.1, 27.7, 51.4, 18.0, 22.2, 34.6, 71.1, 22.9, 34.0], dtype=float)
print(f'Data is \n{age}')
print(f'Коваріація значення:\n{np.cov(salary_in_thousands_new, age)}')
print(f'Коореляція значення:\n{np.corrcoef(salary_in_thousands_new, age)}')
# Out:
# Data is
# [  28.     6.5    6.5    6.5   50.    11.    10.    35.    25.    25.
#     6.5  120.     6.5   50.    50.    55.     0.1 1000. ]
# Мінімальне значення:0.1
# Максимальне значення:1000.0
# Розмах значення:999.9
# Дисперсія (середньо квадратичне відхилення) значення:50278.46333333333
# Стандартне відхилення значення:224.22859615431153
# Data is
# [28.   24.   50.1  34.2  21.   16.8  65.7  54.8  43.33 31.1  27.7  51.4
#  18.   22.2  34.6  71.1  22.9  34.  ]
# Коваріація значення:
# [[53236.02          25.64356863]
#  [   25.64356863   267.44423301]]
# Коореляція значення:
# [[1.         0.00679609]
#  [0.00679609 1.        ]]

# %%
q1 = np.percentile(salary_in_thousands_new, 25)
q2 = np.percentile(salary_in_thousands_new, 50)
q3 = np.percentile(salary_in_thousands_new, 75)

print('Перший квартиль (Q1):', q1)
print('Медиана (Q2), другий квартиль:', q2)
print('Третій квартиль (Q3):', q3)

q_25s = np.percentile(salary_in_thousands_new, [range(25, 100, 25)])
q_10s = np.percentile(salary_in_thousands_new, [range(10, 100, 10)])
q_5s = np.percentile(salary_in_thousands_new, [range(5, 100, 5)])
q_1s = np.percentile(salary_in_thousands_new, [range(1, 100, 1)])

print('Квартилі:', q_25s)
print('Децилі:', q_10s)
print('Вентилі:', q_5s)
print('Перцентилі:', q_1s)
# Out:
# Перший квартиль (Q1): 6.5
# Медиана (Q2), другий квартиль: 25.0
# Третій квартиль (Q3): 50.0
# Квартилі: [[ 6.5 25.  50. ]]
# Децилі: [[ 6.5   6.5   6.85 10.8  25.   29.4  48.5  50.   74.5 ]]
# Вентилі: [[  5.54    6.5     6.5     6.5     6.5     6.85    9.825  10.8    20.1
#    25.     26.05   29.4    35.75   48.5    50.     50.     52.25   74.5
#   252.   ]]
# Перцентилі: [[  1.188   2.276   3.364   4.452   5.54    6.5     6.5     6.5     6.5
#     6.5     6.5     6.5     6.5     6.5     6.5     6.5     6.5     6.5
#     6.5     6.5     6.5     6.5     6.5     6.5     6.5     6.5     6.5
#     6.5     6.5     6.85    7.445   8.04    8.635   9.23    9.825  10.12
#    10.29   10.46   10.63   10.8    10.97   12.96   15.34   17.72   20.1
#    22.48   24.86   25.     25.     25.     25.     25.     25.03   25.54
#    26.05   26.56   27.07   27.58   28.21   29.4    30.59   31.78   32.97
#    34.16   35.75   38.3    40.85   43.4    45.95   48.5    50.     50.
#    50.     50.     50.     50.     50.     50.     50.     50.     50.
#    50.     50.55   51.4    52.25   53.1    53.95   54.8    63.45   74.5
#    85.55   96.6   107.65  118.7   252.    401.6   551.2   700.8   850.4  ]]

# %% [markdown]
# # Pandas

# %% [markdown]
# ## Series

# %%
#pip install pandas==1.5.3
import pandas as pd #panel data
pd.__version__
# Out:
# '1.5.3'

# %%
salary_series = pd.Series(salary_in_thousands_new)
print(salary_series)
print(f'Name of Series {salary_series.name}')
print(f'Number of diminsions {salary_series.ndim}')
print(f'Shape {salary_series.shape}')
print(f'Size {salary_series.size}')
print(f'Dtype {salary_series.dtype}')
print(f'Indexes {salary_series.index}')
print(f'Values {salary_series.values}')
# Out:
# 0       28.0
# 1        6.5
# 2        6.5
# 3        6.5
# 4       50.0
# 5       11.0
# 6       10.0
# 7       35.0
# 8       25.0
# 9       25.0
# 10       6.5
# 11     120.0
# 12       6.5
# 13      50.0
# 14      50.0
# 15      55.0
# 16       0.1
# 17    1000.0
# dtype: float64
# Name of Series None
# Number of diminsions 1
# Shape (18,)
# Size 18
# Dtype float64
# Indexes RangeIndex(start=0, stop=18, step=1)
# Values [  28.     6.5    6.5    6.5   50.    11.    10.    35.    25.    25.
#     6.5  120.     6.5   50.    50.    55.     0.1 1000. ]

# %%
salary_series.name = 'My_series'
salary_series.index = range(2, 20, 1)

print(salary_series, '\n')
print(f'Name of Series {salary_series.name}')
print(f'Indexes {salary_series.index}')
# Out:
# 2       28.0
# 3        6.5
# 4        6.5
# 5        6.5
# 6       50.0
# 7       11.0
# 8       10.0
# 9       35.0
# 10      25.0
# 11      25.0
# 12       6.5
# 13     120.0
# 14       6.5
# 15      50.0
# 16      50.0
# 17      55.0
# 18       0.1
# 19    1000.0
# Name: My_series, dtype: float64
#
# Name of Series My_series
# Indexes RangeIndex(start=2, stop=20, step=1)

# %%
salary_series = pd.Series(salary_in_thousands_new,
                          index = range(2, 20, 1),
                          name = 'My_series',
                          dtype = float
                          )
print(salary_series)
# Out:
# 2       28.0
# 3        6.5
# 4        6.5
# 5        6.5
# 6       50.0
# 7       11.0
# 8       10.0
# 9       35.0
# 10      25.0
# 11      25.0
# 12       6.5
# 13     120.0
# 14       6.5
# 15      50.0
# 16      50.0
# 17      55.0
# 18       0.1
# 19    1000.0
# Name: My_series, dtype: float64

# %%
mountains_height = pd.Series(
    data=[2061, 2035.8, 2028.5, np.nan, np.nan],
    index=["Goverla", "Brebenskyl", "Pip_Ivan", "Petros", "Gutin_Tomnatik"],
    name="Height, m",
    dtype=float,
)
# Cлайсування та індексація
print(mountains_height)
print(mountains_height[0])
print(mountains_height["Goverla"])
print(mountains_height[["Pip_Ivan", "Goverla", "Gutin_Tomnatik"]])
print(mountains_height[1:3])
print(mountains_height["Brebenskyl":"Petros"])
print(mountains_height.Petros)
print(mountains_height.Brebenskyl)
# Out:
# Goverla           2061.0
# Brebenskyl        2035.8
# Pip_Ivan          2028.5
# Petros               NaN
# Gutin_Tomnatik       NaN
# Name: Height, m, dtype: float64
# 2061.0
# 2061.0
# Pip_Ivan          2028.5
# Goverla           2061.0
# Gutin_Tomnatik       NaN
# Name: Height, m, dtype: float64
# Brebenskyl    2035.8
# Pip_Ivan      2028.5
# Name: Height, m, dtype: float64
# Brebenskyl    2035.8
# Pip_Ivan      2028.5
# Petros           NaN
# Name: Height, m, dtype: float64
# nan
# 2035.8

# %%
# Фільтрування та "мАски"
print(mountains_height > 2030)
print()
print(mountains_height[mountains_height > 2030])
print()
print("Goverla" in mountains_height)
# Out:
# Goverla            True
# Brebenskyl         True
# Pip_Ivan          False
# Petros            False
# Gutin_Tomnatik    False
# Name: Height, m, dtype: bool
#
# Goverla       2061.0
# Brebenskyl    2035.8
# Name: Height, m, dtype: float64
#
# True

# %%
#Cортування
sort_index = mountains_height.sort_index()
print(sort_index)
print()
mountains_height.sort_values(inplace=True, ascending=True)
print(mountains_height)
# Out:
# Brebenskyl        2035.8
# Goverla           2061.0
# Gutin_Tomnatik       0.0
# Petros               0.0
# Pip_Ivan          2028.5
# Name: Height, m, dtype: float64
#
# Petros               0.0
# Gutin_Tomnatik       0.0
# Pip_Ivan          2028.5
# Brebenskyl        2035.8
# Goverla           2061.0
# Name: Height, m, dtype: float64

# %%
# Додаткові функції
mountains_height.fillna(0, inplace=True)
print(mountains_height)
# Out:
# Goverla           2061.0
# Brebenskyl        2035.8
# Pip_Ivan          2028.5
# Petros               0.0
# Gutin_Tomnatik       0.0
# Name: Height, m, dtype: float64

# %% [markdown]
# ## DataFrames

# %%
contacts = pd.DataFrame(
    {
        "name": [
            "Allen Raymond",
            "Chaim Lewis",
            "Kennedy Lane",
            "Wylie Pope",
            "Cyrus Jackson",
        ],
        "email": [
            "nulla.ante@vestibul.co.uk",
            "dui.in@egetlacus.ca",
            "mattis.Cras@nonenimMauris.net",
            "est@utquamvel.net",
            "nibh@semsempererat.com",
        ],
        "phone": [
            "(992) 914-3792",
            "(294) 840-6685",
            "(542) 451-7038",
            "(692) 802-2949",
            "(501) 472-5218",
        ],
        "favorite": [False, False, True, False, True],
    },
    index=[1, 2, 3, 4, 5],
)

contacts
# Out:
#             name                          email           phone  favorite
# 1  Allen Raymond      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 2    Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 3   Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 4     Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 5  Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True

# %%
# Слайсування та індексація
print(contacts["name"])
print()
print(contacts.loc[1])
print()
print(contacts.iloc[1])
print()
print(contacts[0:2])
print()
print(contacts[contacts["favorite"]])
# Out:
# 1    Allen Raymond
# 2      Chaim Lewis
# 3     Kennedy Lane
# 4       Wylie Pope
# 5    Cyrus Jackson
# Name: name, dtype: object
#
# name                    Allen Raymond
# email       nulla.ante@vestibul.co.uk
# phone                  (992) 914-3792
# favorite                        False
# Name: 1, dtype: object
#
# name                Chaim Lewis
# email       dui.in@egetlacus.ca
# phone            (294) 840-6685
# favorite                  False
# Name: 2, dtype: object
#
#             name                      email           phone  favorite
# 1  Allen Raymond  nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 2    Chaim Lewis        dui.in@egetlacus.ca  (294) 840-6685     False
#
#             name                          email           phone  favorite
# 3   Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 5  Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True

# %% [markdown]
# Зберігання та зчитування

# %%
contacts.to_csv('contacts.csv',
                sep = ',',
                encoding = 'utf8',
                index = True,
                header = True,
                na_rep = '',
                columns = None
)
contacts_readed = pd.read_csv("contacts.csv",
                              sep = ',',
                              encoding = 'utf8',
                              #nrows = 1,
                              dtype = str
                              )

# %%
contacts.to_excel('contacts.xlsx',
                  sheet_name='Contacts',
                  na_rep='',
                  columns=None,
                  header=True,
                  index=True,
                  engine = None
                  )
contacts = pd.read_excel("contacts.xlsx",
                         sheet_name = 'Contacts',
                         dtype = str,
                         engine = None
                         )

# %%
contacts.to_json('contacts.json',
                  orient="split", # records  index  columns  values
                  )
contacts = pd.read_json("contacts.json",
                         orient = "split"
                         )

# %%
tmp = pd.read_html("https://statisticstimes.com/tech/top-computer-languages.php",
                   attrs={"id": "table_id1"},
                   )

print(tmp[0].head())
# Out:
#    Dec 2023 Change Programming language    Share  Trends
# 0         1    NaN               Python  28.09 %  +0.1 %
# 1         2    NaN                 Java  15.81 %  -0.9 %
# 2         3    NaN           JavaScript   8.93 %  -0.5 %
# 3         4      ↑                C/C++    6.8 %  +0.1 %
# 4         5      ↓                   C#   6.64 %  -0.3 %

# %% [markdown]
# # Робота з даними

# %% [markdown]
# Додавання

# %%
# contacts['name'][1] == contacts.loc[1, 'name']
print(contacts.loc[1, 'name'])
contacts.loc[1, 'name'] = 'Allen RaymondNew'
print(contacts.loc[1, 'name'])
contacts['job'] = ['HR', 'Dev', 'Data Scientist', 'Dev', 'ML Engineer']
display(contacts)
# Out:
# Allen Raymond
# Allen RaymondNew
#                name                          email           phone  favorite  \
# 1  Allen RaymondNew      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 2       Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 3      Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 4        Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 5     Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True
#
#               job
# 1              HR
# 2             Dev
# 3  Data Scientist
# 4             Dev
# 5     ML Engineer

# %%
contacts = contacts.append(pd.Series(['Serhii Kulikov', 'sk@gmail.com', '(000) 911-3432', True, 'DS lecturer'],
                          ['name', 'email', 'phone', 'favorite', 'job']),
                ignore_index=True)
contacts
# Out:
# <ipython-input-48-04fd20ec1aa3>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   contacts = contacts.append(pd.Series(['Serhii Kulikov', 'sk@gmail.com', '(000) 911-3432', True, 'DS lecturer'],
#                name                          email           phone  favorite  \
# 0  Allen RaymondNew      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 1       Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 2      Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 3        Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 4     Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True
# 5    Serhii Kulikov                   sk@gmail.com  (000) 911-3432      True
#
#               job
# 0              HR
# 1             Dev
# 2  Data Scientist
# 3             Dev
# 4     ML Engineer
# 5     DS lecturer

# %% [markdown]
# Віднімання

# %%
contacts.drop(columns = ['job'])
# Out:
#                name                          email           phone  favorite
# 0  Allen RaymondNew      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 1       Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 2      Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 3        Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 4     Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True
# 5    Serhii Kulikov                   sk@gmail.com  (000) 911-3432      True

# %%
contacts.drop('job', axis = 1)
# Out:
#                name                          email           phone  favorite
# 0  Allen RaymondNew      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 1       Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 2      Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 3        Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 4     Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True
# 5    Serhii Kulikov                   sk@gmail.com  (000) 911-3432      True

# %%
contacts.drop(columns = ['job'])
# Out:
#                name                          email           phone  favorite
# 0  Allen RaymondNew      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 1       Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 2      Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 3        Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 4     Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True
# 5    Serhii Kulikov                   sk@gmail.com  (000) 911-3432      True

# %% [markdown]
# Об'єднання

# %%
contacts2 = pd.DataFrame(    {
        "name": [
            "Vasyl Petrenko",
            "Diana Chornyava"
        ],
        "email": [
            "v.p@gmail.com",
            "d.c@gmail.com"
        ],
        "phone": [
            "(001) 914-3792",
            "(002) 840-6685",
        ],
        "favorite": [
            False,
            False
        ]
    },
    index=[6, 7] # 6, 7
                             )
final_contacts = pd.concat([contacts, contacts2], axis = 0)
final_contacts
# Out:
#                name                          email           phone  favorite  \
# 0  Allen RaymondNew      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 1       Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 2      Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 3        Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 4     Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True
# 5    Serhii Kulikov                   sk@gmail.com  (000) 911-3432      True
# 6    Vasyl Petrenko                  v.p@gmail.com  (001) 914-3792     False
# 7   Diana Chornyava                  d.c@gmail.com  (002) 840-6685     False
#
#               job
# 0              HR
# 1             Dev
# 2  Data Scientist
# 3             Dev
# 4     ML Engineer
# 5     DS lecturer
# 6             NaN
# 7             NaN

# %%
final_contacts = contacts.merge(contacts2,
               how = 'outer',
               #on = 'name'
               )
final_contacts
# Out:
#                name                          email           phone  favorite  \
# 0  Allen RaymondNew      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 1       Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 2      Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 3        Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 4     Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True
# 5    Serhii Kulikov                   sk@gmail.com  (000) 911-3432      True
# 6    Vasyl Petrenko                  v.p@gmail.com  (001) 914-3792     False
# 7   Diana Chornyava                  d.c@gmail.com  (002) 840-6685     False
#
#               job
# 0              HR
# 1             Dev
# 2  Data Scientist
# 3             Dev
# 4     ML Engineer
# 5     DS lecturer
# 6             NaN
# 7             NaN

# %% [markdown]
# Очищення

# %%
final_contacts['nan_col'] = np.nan
final_contacts
# Out:
#                name                          email           phone  favorite  \
# 0  Allen RaymondNew      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 1       Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 2      Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 3        Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 4     Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True
# 5    Serhii Kulikov                   sk@gmail.com  (000) 911-3432      True
# 6    Vasyl Petrenko                  v.p@gmail.com  (001) 914-3792     False
# 7   Diana Chornyava                  d.c@gmail.com  (002) 840-6685     False
#
#               job  nan_col
# 0              HR      NaN
# 1             Dev      NaN
# 2  Data Scientist      NaN
# 3             Dev      NaN
# 4     ML Engineer      NaN
# 5     DS lecturer      NaN
# 6             NaN      NaN
# 7             NaN      NaN

# %%
final_contacts = final_contacts.dropna(axis = 1, how = 'all')
final_contacts
# Out:
#                name                          email           phone  favorite  \
# 0  Allen RaymondNew      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 1       Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 2      Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 3        Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 4     Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True
# 5    Serhii Kulikov                   sk@gmail.com  (000) 911-3432      True
# 6    Vasyl Petrenko                  v.p@gmail.com  (001) 914-3792     False
# 7   Diana Chornyava                  d.c@gmail.com  (002) 840-6685     False
#
#               job
# 0              HR
# 1             Dev
# 2  Data Scientist
# 3             Dev
# 4     ML Engineer
# 5     DS lecturer
# 6             NaN
# 7             NaN

# %%
final_contacts = final_contacts.fillna('No INFO')
final_contacts
# Out:
#                name                          email           phone  favorite  \
# 0  Allen RaymondNew      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 1       Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 2      Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 3        Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 4     Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True
# 5    Serhii Kulikov                   sk@gmail.com  (000) 911-3432      True
# 6    Vasyl Petrenko                  v.p@gmail.com  (001) 914-3792     False
# 7   Diana Chornyava                  d.c@gmail.com  (002) 840-6685     False
#
#               job  nan_col
# 0              HR  No INFO
# 1             Dev  No INFO
# 2  Data Scientist  No INFO
# 3             Dev  No INFO
# 4     ML Engineer  No INFO
# 5     DS lecturer  No INFO
# 6         No INFO  No INFO
# 7         No INFO  No INFO

# %%
data = {
    "name": ["Michael", "Steve", "Liza", "Jhon", "Liza", "Jhon"],
    "country": ["Canada", "USA", "Australia", "Denmark", "Australia", "Denmark"],
    "age": [25, 32, 19, 23, 19, 23]
}
employees = pd.DataFrame(data)
display(employees)
employees = employees.drop_duplicates(['country'], keep = 'first')
display(employees)
# Out:
#       name    country  age
# 0  Michael     Canada   25
# 1    Steve        USA   32
# 2     Liza  Australia   19
# 3     Jhon    Denmark   23
# 4     Liza  Australia   19
# 5     Jhon    Denmark   23
#       name    country  age
# 0  Michael     Canada   25
# 1    Steve        USA   32
# 2     Liza  Australia   19
# 3     Jhon    Denmark   23

# %%
employees.index = [1,2,3,4]

# %% [markdown]
# # Часові ряди

# %%
date = pd.Timestamp("2021-09-10")
print(date)
date = pd.to_datetime("2021-09-10 2:54:13")
print(date)
# Out:
# 2021-09-10 00:00:00
# 2021-09-10 02:54:13

# %%
date = pd.date_range(start='2021-09-01', freq='D', periods=8)
temperature = pd.Series([23, 17, 17, 16, 15, 14, 17, 20], index=date)
print(temperature)
# Out:
# 2021-09-01    23
# 2021-09-02    17
# 2021-09-03    17
# 2021-09-04    16
# 2021-09-05    15
# 2021-09-06    14
# 2021-09-07    17
# 2021-09-08    20
# Freq: D, dtype: int64
